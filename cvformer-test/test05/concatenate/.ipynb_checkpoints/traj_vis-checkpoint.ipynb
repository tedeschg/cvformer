# %%
import mdtraj as md
import nglview as nv

traj = md.load("traj_fit.xtc", top="./home/tedeschg/prj/cvformer/cvformer-test/test05/05.mtd_test-05_plain_cvformer/npt.pdb")
view = nv.show_mdtraj(traj)
view
# Out:
# /home/tedeschg/miniforge3/envs/cvformer/lib/python3.10/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 4
#       1 import mdtraj as md
#       2 import nglview as nv
# ----> 4 traj = md.load("traj_fit.xtc", top="./home/tedeschg/prj/cvformer/cvformer-test/test05/05.mtd_test-05_plain_cvformer/npt.pdb")
#       5 view = nv.show_mdtraj(traj)
#       6 view
#
# File ~/miniforge3/envs/cvformer/lib/python3.10/site-packages/mdtraj/core/trajectory.py:398, in load(filename_or_filenames, discard_overlapping_frames, **kwargs)
#     396 if top is None:
# ...
